# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
ipl=pd.read_csv("matches.csv")
ipl
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 750  11346    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
ipl.size
# Out:
# 13590

# %%
ipl.shape
# Out:
# (755, 18)

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.tail()
# Out:
#         id  season           city        date                  team1  \
# 750  11346    2019         Mohali  05-05-2019    Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
#
#                    team2          toss_winner toss_decision  result  \
# 750      Kings XI Punjab      Kings XI Punjab         field  normal
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 750           0      Kings XI Punjab            0               6
# ...

# %%
ipl.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    755.000000   755.000000  755.000000   755.000000      755.000000
# mean    1779.433113  2013.437086    0.025166    13.299338        3.354967
# std     3448.993305     3.363039    0.156732    23.482437        3.388009
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.500000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.000000  2013.000000    0.000000     0.000000        4.000000
# 75%      566.500000  2016.000000    0.000000    19.000000        6.000000
# max    11414.000000  2019.000000    1.000000   146.000000       10.000000

# %%
ipl.ndim
# Out:
# 2

# %%
ipl.sample()
# Out:
#       id  season       city        date           team1                team2  \
# 587  588    2016  Hyderabad  18-04-2016  Mumbai Indians  Sunrisers Hyderabad
#
#              toss_winner toss_decision  result  dl_applied  \
# 587  Sunrisers Hyderabad         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 587  Sunrisers Hyderabad            0               7       DA Warner
#
#                                          venue          umpire1    umpire2  \
# 587  Rajiv Gandhi International Stadium, Uppal  HDPK Dharmasena  VK Sharma
#
#     umpire3
# 587     NaN

# %%
#man of the match awards counts of each player
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %%
#man of the match awards counts of first 10 players
ipl['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: count, dtype: int64

# %%
#man of the match awards counts of top 10 players
ipl['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: count, dtype: int64

# %%
#man of the match awards counts of top 5 players
ipl['player_of_match'].value_counts()[0:5]
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# Name: count, dtype: int64

# %%
#man of the match awards counts of top 5 players list format of just there counts
list(ipl['player_of_match'].value_counts()[0:5])
# Out:
# [21, 20, 17, 17, 17]

# %%
#man of the match awards counts of top 5 players list format of keys or names of players
list(ipl['player_of_match'].value_counts()[0:5].keys())
# Out:
# ['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner']

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['player_of_match'].value_counts()[0:5].keys()),list(ipl['player_of_match'].value_counts()[0:5]))
plt.show()

# %%
#resut
ipl['result'].value_counts()
# Out:
# result
# normal       742
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
#result
plt.figure(figsize=(8,5))
plt.bar(list(ipl['result'].value_counts()[0:5].keys()),list(ipl['result'].value_counts()[0:5]))
plt.show()

# %%
#toss winners
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 97
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
#extracting the records of team who won when the bat first
bf=ipl[ipl['toss_winner']!=0]
bf.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#extracting the records of team for toss decision
bf=ipl[ipl['toss_decision']!='field']
bf.head()
# Out:
#     id  season       city        date                        team1  \
# 4    5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 7    8    2017     Indore  10-04-2017  Royal Challengers Bangalore
# 14  15    2017      Delhi  15-04-2017             Delhi Daredevils
# 17  18    2017      Delhi  17-04-2017             Delhi Daredevils
# 20  21    2017  Hyderabad  19-04-2017          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 14        Kings XI Punjab             Delhi Daredevils           bat  normal
# 17  Kolkata Knight Riders             Delhi Daredevils           bat  normal
# 20       Delhi Daredevils          Sunrisers Hyderabad           bat  normal
#
#     dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
#creating a plot of win by runs
plt.figure(figsize=(8,5))
plt.hist(bf['win_by_runs'])
plt.title('Distribution of runs')
plt.xlabel('runs')
plt.show()

# %%
#no of wins wrt each team after batting first
bf['winner'].value_counts()
# Out:
# winner
# Chennai Super Kings            52
# Mumbai Indians                 44
# Kolkata Knight Riders          35
# Rajasthan Royals               34
# Delhi Daredevils               29
# Royal Challengers Bangalore    26
# Kings XI Punjab                21
# Sunrisers Hyderabad            21
# Deccan Chargers                14
# Pune Warriors                   9
# Rising Pune Supergiants         2
# Gujarat Lions                   2
# Delhi Capitals                  2
# Name: count, dtype: int64

# %%
#creating a plot of tp 3 teams winners
plt.figure(figsize=(6,5))
plt.bar(list(ipl['winner'].value_counts()[0:3].keys()),list(ipl['winner'].value_counts()[0:3]))
plt.title('Winners')
plt.xlabel('runs')
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(ipl['winner'].value_counts()[0:3]),labels=list(ipl['winner'].value_counts()[0:3].keys()))
plt.show()
